# %%
import datetime as dt
import json
from operator import itemgetter

import numpy as np
import scipy.stats as stats
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from game_lists_site.models import (
    Game,
    GameCBR,
    GameDeveloper,
    GameGenre,
    GameStats,
    GameTag,
    System,
    User,
    UserCBR,
    UserGame,
    UserMBCF,
    db,
    user_data_dir,
)
from game_lists_site.utils.utils import days_delta, get_game_stats, normalize_dict

# %%
db.rollback()
# user.last_cbr_update_time = None
# user.save()
# game = Game.get_by_id(412020)

# %%
import concurrent.futures
import os
from unittest import result


def get_normalized_playtimes_new(
    min_player_count=10, normalize=True, zscore_norm=False
):
    games = [
        gs.game
        for gs in GameStats.select(GameStats.game).where(
            GameStats.player_count >= min_player_count
        )
    ]
    users_games = (
        UserGame.select(UserGame.playtime, UserGame.user)
        .where(UserGame.playtime > 0))
    result = {}
    for game in games:
        users_game = users_games.where(UserGame.game == game)
        playtimes = [user_game.playtime for user_game in users_game]
        if normalize:
            if zscore_norm:
                playtimes = stats.zscore(playtimes)
            else:
                playtimes = preprocessing.normalize([playtimes])[0]
        result[game.id] = {
            ug.user.id: playtime for ug, playtime in zip(users_game, playtimes)
        }
    return result
get_normalized_playtimes_new()
# Out:
# {459820: {76561198415178237: 0.0013916893149904775,
#   76561198452902527: 0.0008564241938402939,
#   76561198372055801: 0.00010705302423003674,
#   76561198083927532: 0.11144219822346824,
#   76561198083928469: 0.0056738102841919465,
#   76561198190400041: 0.010277090326083526,
#   76561198118032525: 0.18637931518449397,
#   76561198194383594: 0.005352651211501837,
#   76561198189673933: 0.003211590726901102,
#   76561198397084477: 0.10855176656925725,
#   76561198304593630: 0.03168769517209087,
#   76561198276546837: 0.00010705302423003674,
#   76561198184586273: 0.9694721874272126},
#  380840: {76561198796145774: 0.0013975096269725402,
#   76561198112999216: 0.010847336628405908,
#   76561198157974457: 0.000532384619799063,
#   76561198260719093: 0.9992859313628412,
#   76561198083927802: 0.007786125064561296,
#   76561198083928130: 0.001464057704447423,
#   76561198138848769: 0.0008651250071734773,
#   76561198209914487: 0.0001996442324246486,
#   76561198194383594: 0.0017967980918218375,
#   76561198390246337: 0.004059432725967855,
#   76561198099774641: 0.0011978653945478918,
#   76561198179409498: 0.0034605000286939093,
#   76561198095549375: 0.03347368296986608,
#   76561198204106329: 0.00951637507890825,
#   76561198835309321: 6.654807747488287e-05},
#  442080: {76561198277591112: 0.00275730070532965,
#   76561198173193286: 0.0026622213706631102,
#   76561198120289380: 0.0190634066006412,
#   76561198111034521: 0.004777736566993617,
#   76561198831431504: 0.001972896194330698,
#   76561198083928316: 0.0033753163806621578,
#   76561198262260194: 0.004231030392661014,
#   76561198880397310: 0.9997592040186645,
#   76561198316836771: 0.003042538709329269,
#   76561198240825120: 0.005989998083991998,
#   76561198087335754: 2.3769833666634914e-05,
#   76561198252993116: 0.000831944178332222,
#   76561198129694655: 0.0012598011843316505},
#  444200: {76561198343626816: 0.00027226303554053126,
#   76561198327005294: 0.021407437455584107,
#   76561198452895520: 0.05593323229568149,
#   76561198305124900: 0.09710009126530307,
#   76561198120497131: 0.48147326360122633,
#   76561198243788170: 0.061750288454432374,
#   76561198844586671: 0.17943380920454624,
#   76561198117487704: 0.21165135100685878},
#  265550: {76561198236108608: 0.034747146734410136,
#   76561198297279061: 0.541669409648638,
#   76561198083927708: 0.2617618387325564,
#   76561198083928306: 0.11350734599907311,
#   76561198138897599: 0.3760413435479497,
#   76561198289622516: 0.06486134057089891,
#   76561198207669763: 0.28917347671192434,
#   76561198422973742: 0.03783578199969104,
#   76561198346447513: 0.23628059779398894,
#   76561198740929723: 0.2609896799162361,
#   76561198086984833: 0.23087548607974734,
#   76561198426867819: 0.006177270530561802,
#   76561198324975848: 0.42005439607820255,
#   76561198150684943: 0.053665037734255655,
#   76561198276546837: 0.013512779285603942,
#   76561198326651263: 0.19110930703925574},
#  362300: {76561198144692745: 5.229811714598037e-05,
#   76561198087005343: 0.00015689435143794112,
#   76561198207239548: 0.0015689435143794112,
#   76561198208421312: 0.00010459623429196074,
#   76561198149283595: 5.229811714598037e-05,
#   76561198083928331: 0.0021965209201311757,
#   76561198098126264: 0.003399377614488724,
#   76561198191597810: 0.9995739130111229,
#   76561198099774641: 5.229811714598037e-05,
#   76561198129135351: 5.229811714598037e-05,
#   76561198139711708: 0.0016212416315253915,
#   76561198156634666: 0.024632413175756755,
#   76561198255142197: 0.014957261503750386},
#  ...}

# %%
def get_normalized_playtimes(min_player_count=10, normalize=True, zscore_norm=False):
    system, _ = System.get_or_create(key="NormalizedPlaytime")
    if not system.date_time_value or days_delta(system.date_time_value) >= 7 or True:
        games = [
            game
            for game in Game.select()
            if get_game_stats(game).player_count >= min_player_count
        ]
        result = {}
        for game in games:
            user_games = (
                UserGame.select()
                .where(UserGame.game == game)
                .where(UserGame.playtime > 0)
            )
            playtimes = [user_game.playtime for user_game in user_games]
            normalized_playtimes = []
            if normalize:
                if zscore_norm:
                    normalized_playtimes = stats.zscore(playtimes)
                else:
                    normalized_playtimes = preprocessing.normalize([playtimes])[0]
            else:
                normalized_playtimes = playtimes
            result[game.id] = {
                ug.user.id: normalized_playtime
                for ug, normalized_playtime in zip(user_games, normalized_playtimes)
            }
        with (user_data_dir / "normalized_playtimes.json").open("w") as data_file:
            json.dump(result, data_file)
        system.date_time_value = dt.datetime.now()
        system.save()
        return result
    else:
        with (user_data_dir / "normalized_playtimes.json").open() as data_file:
            result = {
                int(key_a): {int(key_b): value_b for key_b, value_b in value_a.items()}
                for key_a, value_a in json.load(data_file).items()
            }
        return result
# print(len(get_normalized_playtimes()))

# %%
def get_mbcf_for_user(
    target_user,
    max_count=-1,
    max_player_count=16,
    normalize=True,
    corrcoef=True,
    sim_user_count=9,
    zscore_norm = False
):
    system, _ = System.get_or_create(key="UserMBCF")
    if not system.date_time_value or days_delta(system.date_time_value) >= 7 or True:
        normalized_playtimes = get_normalized_playtimes_new(max_player_count, normalize, zscore_norm)
        games = Game.select()
        users = [
            user
            for user in User.select()
            if len(
                UserGame.select()
                .where(UserGame.user == user)
                .where(UserGame.playtime != None)
            )
            >= 10
        ]
        game_vecs = []
        for game in games:
            if not normalized_playtimes.get(game.id):
                continue
            game_vec = {user: 0 for user in users}
            user_games = [
                ug
                for ug in UserGame.select().where(UserGame.game == game)
                if normalized_playtimes[game.id].get(ug.user.id)
            ]
            for ug in user_games:
                if ug.user in game_vec:
                    game_vec[ug.user] = normalized_playtimes[game.id].get(ug.user.id)
            game_vecs.append(list(game_vec.values()))
        game_vecs = np.array(game_vecs, dtype=np.float32)
        user_vecs = np.flip(np.rot90(game_vecs), 0)
        if corrcoef:
            user_vecs = np.corrcoef(user_vecs)
        else:
            user_vecs = cosine_similarity(user_vecs)
        sim_users = {}
        for user, user_vec in zip(users, user_vecs):
            result = {}
            for u, sim in zip(users, user_vec):
                result[u] = float(sim)
            result = dict(
                sorted(result.items(), key=lambda x: x[1], reverse=True)[
                    1 : sim_user_count + 1
                ]
            )
            sim_users[user] = result
        i = 0
        count = len(sim_users)
        for user_a, sim in sim_users.items():
            print(f"{i/count*100:.2f}%", end="")
            print("\r", end="")
            i += 1
            played_games = set()
            played_user_games = (
                UserGame.select()
                .where(UserGame.user == user_a)
                .where(UserGame.playtime > 0)
            )
            if len(played_user_games) > 1:
                quantile = np.quantile(
                    [ug.last_played for ug in played_user_games], 0.10
                )
                check_user_games = [
                    ug for ug in played_user_games if ug.last_played <= quantile
                ]
                for ug in played_user_games:
                    if ug not in check_user_games:
                        played_games.add(ug.game)
                played_games = list(played_games)
            games = {}
            for user_b, value in sim.items():
                for user_game in (
                    UserGame.select()
                    .where(UserGame.user == user_b)
                    .where(UserGame.playtime != None)
                ):
                    game = user_game.game
                    user = user_game.user
                    if (
                        game not in played_games
                        and game.id in normalized_playtimes
                        and user.id in normalized_playtimes[game.id]
                        and game.rating >= 7
                    ):
                        if game.id in games:
                            games[game.id] += (
                                normalized_playtimes[game.id].get(user.id) * value
                            )
                        else:
                            games[game.id] = (
                                normalized_playtimes[game.id].get(user.id) * value
                            )
            games = dict(sorted(games.items(), key=lambda x: x[1], reverse=True))
            user_mbcf, _ = UserMBCF.get_or_create(user=user_a)
            user_mbcf.data = json.dumps(games)
            user_mbcf.save()
        system.date_time_value = dt.datetime.now()
        system.save()
    user_mbcf = UserMBCF.get_or_none(UserMBCF.user == target_user)
    if user_mbcf:
        data = {
            Game.get_by_id(game_id): value
            for game_id, value in json.loads(user_mbcf.data).items()
        }
        if len(data) > max_count:
            return dict(list(data.items())[:max_count])
        else:
            return data
    else:
        return {}

# %%
def get_mbcf_for_user_new(
    target_user,
    max_count=9,
    min_player_count=10,
    min_game_count=20,
    normalize=True,
    zscore_norm=False,
    corrcoef=False,
    sim_user_count=9,
):
    system, _ = System.get_or_create(key="UserMBCF")
    if not system.date_time_value or days_delta(system.date_time_value) >= 7:
        normalized_playtimes = get_normalized_playtimes_new(
            min_player_count, normalize, zscore_norm
        )
        games = [
            gs.game
            for gs in GameStats.select(GameStats.game).where(
                GameStats.player_count >= min_player_count
            )
        ]
        users = [
            user
            for user in User.select()
            if len(
                UserGame.select()
                .where(UserGame.user == user)
                .where(UserGame.playtime != None)
            )
            >= min_game_count
        ]
        game_vecs = []
        for game in games:
            if not normalized_playtimes.get(game.id):
                continue
            game_vec = {user: 0 for user in users}
            user_games = [
                ug
                for ug in UserGame.select(UserGame.user).where(UserGame.game == game)
                if normalized_playtimes[game.id].get(ug.user.id)
            ]
            for ug in user_games:
                if ug.user in game_vec:
                    game_vec[ug.user] = normalized_playtimes[game.id].get(ug.user.id)
            game_vecs.append(list(game_vec.values()))
        game_vecs = np.array(game_vecs, dtype=np.float32)
        user_vecs = np.flip(np.rot90(game_vecs), 0)
        if corrcoef:
            user_vecs = np.corrcoef(user_vecs)
        else:
            user_vecs = cosine_similarity(user_vecs)
        sim_users = {}
        for user, user_vec in zip(users, user_vecs):
            result = {}
            for u, sim in zip(users, user_vec):
                result[u] = float(sim)
            result = dict(
                sorted(result.items(), key=lambda x: x[1], reverse=True)[
                    1 : sim_user_count + 1
                ]
            )
            sim_users[user] = result
        i = 0
        count = len(sim_users)
        for user_a, sim in sim_users.items():
            print(f"{i/count*100:.2f}%", end="")
            print("\r", end="")
            i += 1
            played_games = []
            played_user_games = (
                UserGame.select()
                .where(UserGame.user == user_a)
                .where(UserGame.playtime > 0)
            )
            if len(played_user_games) > 1:
                last_played = np.quantile(
                    [ug.last_played for ug in played_user_games], 0.8
                )
                played_games = [ug for ug in played_user_games.where(UserGame.last_played < last_played)]
            else:
                played_games = [ug.game for ug in played_user_games]
            games = {}
            for user_b, value in sim.items():
                for user_game in (
                    UserGame.select(UserGame.game, UserGame.playtime, UserGame.user)
                    .where(UserGame.user == user_b)
                    .where(UserGame.playtime != None)
                ):
                    game = user_game.game
                    user = user_game.user
                    if (
                        game not in played_games
                        and game.id in normalized_playtimes
                        and user.id in normalized_playtimes[game.id]
                        and game.rating >= 7
                    ):
                        if game.id in games:
                            games[game.id] += (
                                normalized_playtimes[game.id].get(user.id) * value
                            )
                        else:
                            games[game.id] = (
                                normalized_playtimes[game.id].get(user.id) * value
                            )
            games = dict(sorted(games.items(), key=lambda x: x[1], reverse=True))
            user_mbcf, _ = UserMBCF.get_or_create(user=user_a)
            user_mbcf.data = json.dumps(games)
            user_mbcf.save()
        system.date_time_value = dt.datetime.now()
        system.save()
    user_mbcf = UserMBCF.get_or_none(UserMBCF.user == target_user)
    if user_mbcf:
        data = {
            Game.get_by_id(game_id): value
            for game_id, value in json.loads(user_mbcf.data).items()
        }
        return dict(list(data.items())[:max_count])
    else:
        return {}


# system, _ = System.get_or_create(key="UserMBCF")
# system.date_time_value = None
# system.save()
# user = User.get_by_id(76561198083927294)
# get_mbcf_for_user_new(user, 9)

# %%
users = []
for user in User.select():
    count = (
        UserGame.select(UserGame.score)
        .where(UserGame.user == user)
        .where(UserGame.score > 0)
        .count()
    )
    if count >= 10:
        users.append(user)
print(len(users))
# Out:
# 7

# %%
user = User.get_by_id(76561198083927294)
get_mbcf_for_user(user, 9)
# Out:
# /home/nikohonu/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/nikohonu/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 1.01%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [55], line 2
#       1 user = User.get_by_id(76561198083927294)
# ----> 2 get_mbcf_for_user(user, 9)
#
# Cell In [52], line 84, in get_mbcf_for_user(target_user, max_count, max_player_count, normalize, corrcoef, sim_user_count)
#      78 for user_b, value in sim.items():
#      79     for user_game in (
#      80         UserGame.select()
#      81         .where(UserGame.user == user_b)
#      82         .where(UserGame.playtime != None)
#      83     ):
# ---> 84         game = user_game.game
#      85         user = user_game.user
#      86         if (
#      87             game not in played_games
#      88             and game.id in normalized_playtimes
#      89             and user.id in normalized_playtimes[game.id]
#      90             and game.rating >= 7
#      91         ):
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:4560, in ForeignKeyAccessor.__get__(self, instance, instance_type)
#    4558 def __get__(self, instance, instance_type=None):
#    4559     if instance is not None:
# -> 4560         return self.get_rel_instance(instance)
#    4561     return self.field
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:4551, in ForeignKeyAccessor.get_rel_instance(self, instance)
#    4549 if value is not None or self.name in instance.__rel__:
#    4550     if self.name not in instance.__rel__ and self.field.lazy_load:
# -> 4551         obj = self.rel_model.get(self.field.rel_field == value)
#    4552         instance.__rel__[self.name] = obj
#    4553     return instance.__rel__.get(self.name, value)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:6600, in Model.get(cls, *query, **filters)
#    6598 if filters:
#    6599     sq = sq.filter(**filters)
# -> 6600 return sq.get()
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:7048, in BaseModelSelect.get(self, database)
#    7046 clone._cursor_wrapper = None
#    7047 try:
# -> 7048     return clone.execute(database)[0]
#    7049 except IndexError:
#    7050     sql, params = clone.sql()
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:1946, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    1943 if not database:
#    1944     raise InterfaceError('Query must be bound to a database in order '
#    1945                          'to call "%s".' % method.__name__)
# -> 1946 return method(self, database, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:2017, in BaseQuery.execute(self, database)
#    2015 @database_required
#    2016 def execute(self, database):
# -> 2017     return self._execute(database)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:2190, in SelectBase._execute(self, database)
#    2188 def _execute(self, database):
#    2189     if self._cursor_wrapper is None:
# -> 2190         cursor = database.execute(self)
#    2191         self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2192     return self._cursor_wrapper
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:3233, in Database.execute(self, query, commit, **context_options)
#    3231 def execute(self, query, commit=SENTINEL, **context_options):
#    3232     ctx = self.get_sql_context(**context_options)
# -> 3233     sql, params = ctx.sql(query).query()
#    3234     return self.execute_sql(sql, params, commit=commit)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:614, in Context.sql(self, obj)
#     612 def sql(self, obj):
#     613     if isinstance(obj, (Node, Context)):
# --> 614         return obj.__sql__(self)
#     615     elif is_model(obj):
#     616         return obj._meta.table.__sql__(self)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:2469, in Select.__sql__(self, ctx)
#    2463         (ctx
#    2464          .literal('ON ')
#    2465          .sql(EnclosedNodeList(self._distinct))
#    2466          .literal(' '))
#    2468 with ctx.scope_source():
# -> 2469     ctx = self.__sql_selection__(ctx, is_subquery)
#    2471 if self._from_list:
#    2472     with ctx.scope_source(parentheses=False):
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:7409, in ModelSelect.__sql_selection__(self, ctx, is_subquery)
#    7405 if self._is_default and is_subquery and len(self._returning) > 1 and \
#    7406    self.model._meta.primary_key is not False:
#    7407     return ctx.sql(self.model._meta.primary_key)
# -> 7409 return ctx.sql(CommaNodeList(self._returning))
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:614, in Context.sql(self, obj)
#     612 def sql(self, obj):
#     613     if isinstance(obj, (Node, Context)):
# --> 614         return obj.__sql__(self)
#     615     elif is_model(obj):
#     616         return obj._meta.table.__sql__(self)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:1810, in NodeList.__sql__(self, ctx)
#    1808 with ctx(parentheses=self.parens):
#    1809     for i in range(n_nodes - 1):
# -> 1810         ctx.sql(self.nodes[i])
#    1811         ctx.literal(self.glue)
#    1812     ctx.sql(self.nodes[n_nodes - 1])
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:614, in Context.sql(self, obj)
#     612 def sql(self, obj):
#     613     if isinstance(obj, (Node, Context)):
# --> 614         return obj.__sql__(self)
#     615     elif is_model(obj):
#     616         return obj._meta.table.__sql__(self)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:4688, in Field.__sql__(self, ctx)
#    4687 def __sql__(self, ctx):
# -> 4688     return ctx.sql(self.column)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:614, in Context.sql(self, obj)
#     612 def sql(self, obj):
#     613     if isinstance(obj, (Node, Context)):
# --> 614         return obj.__sql__(self)
#     615     elif is_model(obj):
#     616         return obj._meta.table.__sql__(self)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:1279, in Column.__sql__(self, ctx)
#    1277     return ctx.sql(Entity(self.name))
#    1278 else:
# -> 1279     with ctx.scope_column():
#    1280         return ctx.sql(self.source).literal('.').sql(Entity(self.name))
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:549, in __scope_context__.<locals>.inner(self, **kwargs)
#     547 @contextmanager
#     548 def inner(self, **kwargs):
# --> 549     with self(scope=scope, **kwargs):
#     550         yield self
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:587, in Context.__call__(self, **overrides)
#     584     del overrides['scope']
#     586 self.stack.append(self.state)
# --> 587 self.state = self.state(**overrides)
#     588 return self
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:540, in State.__call__(self, scope, parentheses, **kwargs)
#     538 else:
#     539     settings = self.settings
# --> 540 return State(scope, parentheses, **settings)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:525, in State.__new__(cls, scope, parentheses, **kwargs)
#     523 class State(collections.namedtuple('_State', ('scope', 'parentheses',
#     524                                               'settings'))):
# --> 525     def __new__(cls, scope=SCOPE_NORMAL, parentheses=False, **kwargs):
#     526         return super(State, cls).__new__(cls, scope, parentheses, kwargs)
#     528     def __call__(self, scope=None, parentheses=None, **kwargs):
#     529         # Scope and settings are "inherited" (parentheses is not, however).
#
# KeyboardInterrupt:

# %%
import random
from itertools import combinations_with_replacement

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import clear_output, display

max_accuracy = 0 # 2
best_row = [0, 0, False, False, False, 0]
data = {}
lines = []
for user in users:
    played_user_games = UserGame.select().where(UserGame.user == user).where(UserGame.playtime > 0)
    last_played = np.quantile([ug.last_played for ug in played_user_games], 0.8)
    input_data = played_user_games.where(UserGame.last_played < last_played)
    check_data = played_user_games.where(UserGame.last_played >= last_played)
    data[user] = [input_data, check_data]
for i in range(10000):
    row = [
        21,
        random.randint(1, 50),
        True,
        random.choice([True, False]),
        random.choice([True, False]),
        random.randint(1, 50),
    ]
    system, _ = System.get_or_create(key="UserMBCF")
    system.date_time_value = None
    system.save()
    accuracy = []
    for user, d in data.items():
        result = get_mbcf_for_user_new(user, d[0].count(), row[0], row[1], row[2], row[3], row[4], row[5])
        intersection_count = len(set([ug.game for ug in d[1]]).intersection(list(result.keys())))
        accuracy.append(intersection_count / len(d[1]))
    accuracy = np.mean(accuracy)
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        best_row = row
    lines.append(row + [accuracy])
    clear_output(wait=True)
    print(f"Iteration #{i}")
    print("row", row)
    print(accuracy)
    print("-"*24)
    print(f"Best Iteration")
    print("row", best_row)
    print(max_accuracy)
    print("-"*24)
    df = pd.DataFrame(lines)
    df.to_csv("result2.csv", index=False)
# clear_output(wait=True)
# Out:
# Iteration #22
# row [21, 46, True, False, True, 27]
# 0.2058207898544033
# ------------------------
# Best Iteration
# row [21, 17, True, False, False, 10]
# 0.28301628343645147
# ------------------------
# 24.27%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [22], line 32
#      30 accuracy = []
#      31 for user, d in data.items():
# ---> 32     result = get_mbcf_for_user_new(user, d[0].count(), row[0], row[1], row[2], row[3], row[4], row[5])
#      33     intersection_count = len(set([ug.game for ug in d[1]]).intersection(list(result.keys())))
#      34     accuracy.append(intersection_count / len(d[1]))
#
# Cell In [20], line 90, in get_mbcf_for_user_new(target_user, max_count, min_player_count, min_game_count, normalize, zscore_norm, corrcoef, sim_user_count)
#      84 for user_game in (
#      85     UserGame.select(UserGame.game, UserGame.playtime, UserGame.user)
#      86     .where(UserGame.user == user_b)
#      87     .where(UserGame.playtime != None)
#      88 ):
#      89     game = user_game.game
# ---> 90     user = user_game.user
#      91     if (
#      92         game not in played_games
#      93         and game.id in normalized_playtimes
#      94         and user.id in normalized_playtimes[game.id]
#      95         and game.rating >= 7
#      96     ):
#      97         if game.id in games:
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:4560, in ForeignKeyAccessor.__get__(self, instance, instance_type)
#    4558 def __get__(self, instance, instance_type=None):
#    4559     if instance is not None:
# -> 4560         return self.get_rel_instance(instance)
#    4561     return self.field
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:4551, in ForeignKeyAccessor.get_rel_instance(self, instance)
#    4549 if value is not None or self.name in instance.__rel__:
#    4550     if self.name not in instance.__rel__ and self.field.lazy_load:
# -> 4551         obj = self.rel_model.get(self.field.rel_field == value)
#    4552         instance.__rel__[self.name] = obj
#    4553     return instance.__rel__.get(self.name, value)
#
# File ~/.cache/pypoetry/virtualenvs/game-lists-site-LdBYsaDo-py3.10/lib/python3.10/site-packages/peewee.py:6600, in Model.get(cls, *query, **filters)
#    6598 if filters:
#    6599     sq = sq.filter(**filters)
# -> 6600 return sq.get()
#
# KeyboardInterrupt:
